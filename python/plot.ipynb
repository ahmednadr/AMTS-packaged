# %% [markdown]
# 40 Mbps per vm
# single count size 320 bytes
# report frequency 10s (5s)
# report QOS bandwidth 1 Mbps (Network monitoring tool bandwidth requirements)
# can be minimized to a single metric report every 360*10 seconds so QOS rate 3.2 kb/hr
#
#
# available bw 5 mb
# 7 mb

# %%
import pandas as pd

headers = ['seconds', 'value']

df = pd.read_csv('/usr/src/AMTS/AMTS python package/python/metrics 2/vm 1 BW metrics.csv', names=headers ,sep = '|')

df[15000:].set_index('seconds').plot()
# Out:
# <AxesSubplot:xlabel='seconds'>

# %%
headers = ['seconds', 'value']

df = pd.read_csv('/usr/src/AMTS/AMTS python package/python/metrics 1/CPU Metrics Output.csv', names=headers ,sep = '|')

df.set_index('seconds').plot()
# Out:
# <AxesSubplot:xlabel='seconds'>

# %%
headers = ['seconds', 'value']

df = pd.read_csv('/usr/src/AMTS/AMTS python package/python/metrics 1/CPU Metrics Output.csv', names=headers ,sep = '|')

df.set_index('seconds').plot()
# Out:
# <AxesSubplot:xlabel='seconds'>

# %%
headers = ['seconds', 'value']

df = pd.read_csv('/usr/src/AMTS/AMTS python package/java/ysb.csv' , names = headers,sep = '|')
df = df[1:].astype(float)
df.set_index('seconds').plot()
# Out:
# <ipython-input-29-8f95716eaead>:3: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/usr/src/AMTS/AMTS python package/java/ysb.csv' , names = headers,sep = '|')
# <AxesSubplot:xlabel='seconds'>
